# %%
pip install folium
# Out:
# Collecting folium
#   Downloading folium-0.19.5-py2.py3-none-any.whl.metadata (4.1 kB)
# Collecting branca>=0.6.0 (from folium)
#   Downloading branca-0.8.1-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: jinja2>=2.9 in c:\users\shann\anaconda3\lib\site-packages (from folium) (3.1.3)
# Requirement already satisfied: numpy in c:\users\shann\anaconda3\lib\site-packages (from folium) (1.26.4)
# Requirement already satisfied: requests in c:\users\shann\anaconda3\lib\site-packages (from folium) (2.31.0)
# Requirement already satisfied: xyzservices in c:\users\shann\anaconda3\lib\site-packages (from folium) (2022.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\shann\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\shann\anaconda3\lib\site-packages (from requests->folium) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\shann\anaconda3\lib\site-packages (from requests->folium) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\shann\anaconda3\lib\site-packages (from requests->folium) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\shann\anaconda3\lib\site-packages (from requests->folium) (2024.2.2)
# Downloading folium-0.19.5-py2.py3-none-any.whl (110 kB)
#    ---------------------------------------- 0.0/110.9 kB ? eta -:--:--
#    --- ------------------------------------ 10.2/110.9 kB ? eta -:--:--
#    ------------------------------------ --- 102.4/110.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------- 110.9/110.9 kB 1.3 MB/s eta 0:00:00
# Downloading branca-0.8.1-py3-none-any.whl (26 kB)
# Installing collected packages: branca, folium
# Successfully installed branca-0.8.1 folium-0.19.5
# Note: you may need to restart the kernel to use updated packages.

# %%
# Import necessary libraries
import pandas as pd

# Load the dataset
df = pd.read_csv("C:\\Users\\shann\\Documents\\bird_migration_dataset.csv")

# Display the first few rows
df.head()
# Out:
#              Timestamp         Species   Latitude   Longitude  Speed_kmh  \
# 0  2024-01-01 00:00:00  Whooping Crane  57.855968 -105.088970      29.59
# 1  2024-01-01 00:30:00     Arctic Tern  56.988955 -107.244475      36.79
# 2  2024-01-01 01:00:00     Arctic Tern  54.910968 -101.879439      33.26
# 3  2024-01-01 01:30:00      Snow Goose  64.902712  -97.668528      42.03
# 4  2024-01-01 02:00:00    Barn Swallow  57.155274  -95.808192      27.38
#
#    Altitude_m  Temperature_C  Wind_Speed_mps
# 0     2954.92          17.44            3.88
# 1     2760.67          -1.81            7.87
# 2     1928.49          22.81            4.08
# 3      556.53          14.83            4.86
# 4      357.93          14.99            6.88

# %%
import folium

# Filter migration data for a specific bird species
bird_species = "Arctic Tern"
bird_data = df[df["Species"] == bird_species]

# Create a base map
m = folium.Map(location=[bird_data.iloc[0]["Latitude"], bird_data.iloc[0]["Longitude"]], zoom_start=5)

# Add migration points
for _, row in bird_data.iterrows():
    folium.Marker(
        location=[row["Latitude"], row["Longitude"]],
        popup=f"{row['Species']} - {row['Speed_kmh']} km/h",
        icon=folium.Icon(color="blue", icon="info-sign"),
    ).add_to(m)

# Show the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_905546f3a5bdf4eb9a60c458e8dbedce {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_905546f3a5bdf4eb9a60c458e8dbedce&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_905546f3a5bdf4eb9a60c458e8dbedce = L.map(
#                 &quot;map_905546f3a5bdf4eb9a60c458e8dbedce&quot;,
#                 {
#                     center: [56.98895491934068, -107.24447542959534],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_81359416781d06b4b11260a0476e89b5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_81359416781d06b4b11260a0476e89b5.addTo(map_905546f3a5bdf4eb9a60c458e8dbedce);
#
#
#             var marker_af7f1664ebbec4f4ffc628d1c753d214 = L.marker(
#                 [56.98895491934068, -107.24447542959534],
#                 {
# }
#             ).addTo(map_905546f3a5bdf4eb9a60c458e8dbedce);
#
#
#             var icon_5ccadee8ba5384e78fbc0b1ba9550b0e = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a64feb7aebef2b5b9e4c714caebbe54e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d9da8094c5eaa9280753a09ce879fad = $(`&lt;div id=&quot;html_1d9da8094c5eaa9280753a09ce879fad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arctic Tern - 36.79 km/h&lt;/div&gt;`)[0];
#                 popup_a64feb7aebef2b5b9e4c714caebbe54e.setContent(html_1d9da8094c5eaa9280753a09ce879fad);
#
#
#
#         marker_af7f1664ebbec4f4ffc628d1c753d214.bindPopup(popup_a64feb7aebef2b5b9e4c714caebbe54e)
#         ;
#
#
#
#
#                 marker_af7f1664ebbec4f4ffc628d1c753d214.setIcon(icon_5ccadee8ba5384e78fbc0b1ba9550b0e);
#
#
#             var marker_bfb37d7c6d4e5641fb36f39377897ce9 = L.marker(
#                 [54.91096845753329, -101.87943938320367],
#                 {
# }
#             ).addTo(map_905546f3a5bdf4eb9a60c458e8dbedce);
#
#
#             var icon_6e6cd89d8465f8368ab5ce1797410a48 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_30af2c4cbaf31bec7e261e60f6447e38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9b0d68919bb70a1d971eeff4acf73b7 = $(`&lt;div id=&quot;html_c9b0d68919bb70a1d971eeff4acf73b7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arctic Tern - 33.26 km/h&lt;/div&gt;`)[0];
#                 popup_30af2c4cbaf31bec7e261e60f6447e38.setContent(html_c9b0d68919bb70a1d971eeff4acf73b7);
#
#
#
#         marker_bfb37d7c6d4e5641fb36f39377897ce9.bindPopup(popup_30af2c4cbaf31bec7e261e60f6447e38)
#         ;
#
#
#
#
#                 marker_bfb37d7c6d4e5641fb36f39377897ce9.setIcon(icon_6e6cd89d8465f8368ab5ce1797410a48);
#
#
#             var marker_00f9080162973450e91d8a0ebc983bed = L.marker(
#                 [55.31136891489627, -109.01928907491224],
#                 {
# }
#             ).addTo(map_905546f3a5bdf4eb9a60c458e8dbedce);
#
#
#             var icon_0257c61ff275bf64da626950747c8bcd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;blue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_21c61a25fa373792efea809ff6b35557 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3315d21b0f05065d5ec4164de0466943 = $(`&lt;div id=&quot;html_3315d21b0f05065d5ec4164de0466943&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Arctic Tern - 49.41 km/h&lt;/div&gt;`)[0];
#                 popup_21c61a25fa373792efea809ff6b35557.setContent(html_3315d21b0f05065d5ec4164de0466943);
#
#
#
#         marker_00f9080162973450e91d8a0ebc983bed.bindPopup(popup_21c61a25fa373792efea809ff6b35557)
#         ;
#
#
#
#
#                 marker_00f9080162973450e91d8a0ebc983bed.setIcon(icon_0257c61ff275bf64da626950747c8bcd);
#
#
#             var marker_368d4d3e47917d0c8632bfb06f3e1f03 = L.marker(
#                 [55.04840850153523, -90.5036363687058],
#                 {
# }
#             ).addTo(map_905546f

# %%
import matplotlib.pyplot as plt

# Select one bird species
bird_data = df[df["Species"] == "Arctic Tern"].copy()

# Convert Timestamp to datetime
bird_data["Timestamp"] = pd.to_datetime(bird_data["Timestamp"])

# Plot Speed & Altitude
fig, ax1 = plt.subplots()

ax1.set_xlabel("Time")
ax1.set_ylabel("Speed (km/h)", color="blue")
ax1.plot(bird_data["Timestamp"], bird_data["Speed_kmh"], color="blue", label="Speed")
ax1.tick_params(axis='y', labelcolor="blue")

ax2 = ax1.twinx()  
ax2.set_ylabel("Altitude (m)", color="red")
ax2.plot(bird_data["Timestamp"], bird_data["Altitude_m"], color="red", linestyle="dashed", label="Altitude")
ax2.tick_params(axis='y', labelcolor="red")

fig.autofmt_xdate()
plt.title("Bird Speed & Altitude Over Time")
plt.show()

# %%
df.to_csv("updated_bird_migration_data.csv", index=False)
print("Updated dataset saved!")
# Out:
# Updated dataset saved!
